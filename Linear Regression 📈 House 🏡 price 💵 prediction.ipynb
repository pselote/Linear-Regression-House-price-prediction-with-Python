# %% [markdown]
# # Import all labraries

# %%
import matplotlib
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
d=pd.read_csv("C:/Users/Pradhan/Desktop/DBA/USA_Housing.csv")

# %%
d
# Out:
#      Avg. Area House Age  Avg. Area Number of Rooms  \
# 0               6.989780                   6.620478
# 1               5.362126                   6.393121
# 2               6.919535                   5.993188
# 3               5.551222                   6.517175
# 4               4.018525                   6.992699
# ..                   ...                        ...
# 846             5.662571                   6.848703
# 847             7.014510                   5.458789
# 848             5.789203                   6.415312
# 849             6.036275                   6.538111
# 850             7.250591                   4.805081
#
#      Avg. Area Number of Bedrooms         Price  \
# 0                            2.42  1.573937e+06
# 1                            2.30  7.988695e+05
# 2                            2.27  1.291332e+06
# 3                            2.10  9.292476e+05
# 4                            2.03  1.125693e+06
# ...

# %%
d.head()
# Out:
#    Avg. Area House Age  Avg. Area Number of Rooms  \
# 0             6.989780                   6.620478
# 1             5.362126                   6.393121
# 2             6.919535                   5.993188
# 3             5.551222                   6.517175
# 4             4.018525                   6.992699
#
#    Avg. Area Number of Bedrooms         Price  \
# 0                          2.42  1.573937e+06
# 1                          2.30  7.988695e+05
# 2                          2.27  1.291332e+06
# 3                          2.10  9.292476e+05
# 4                          2.03  1.125693e+06
#
#                                              Address
# 0     972 Joyce Viaduct\nLake William, TN 17778-6483
# 1                          USS Gilbert\nFPO AA 20957
# 2  829 Welch Track Apt. 992\nNorth John, AR 26532...
# 3                           USNS Brown\nFPO AP 85833
# 4       3599 Ramirez Springs\nJacksonhaven, AZ 72798

# %%
d.tail()
# Out:
#      Avg. Area House Age  Avg. Area Number of Rooms  \
# 846             5.662571                   6.848703
# 847             7.014510                   5.458789
# 848             5.789203                   6.415312
# 849             6.036275                   6.538111
# 850             7.250591                   4.805081
#
#      Avg. Area Number of Bedrooms         Price  \
# 846                          2.26  9.440325e+05
# 847                          2.11  1.120943e+06
# 848                          2.02  1.406865e+06
# 849                          2.22  1.378938e+06
# 850                          2.13  1.030730e+06
#
#                                                Address
# 846  775 Gutierrez Corner Suite 080\nEast Ronaldfur...
# 847  2558 King Trail\nEast Catherinebury, MP 23625-...
# 848   0476 Jessica Shoals\nMelissamouth, DE 39609-2777
# 849                   PSC 7442, Box 6234\nAPO AP 13017
# 850  4215 Tracy Garden Suite 076\nJoshualand, VA 01...

# %%
d.shape
# Out:
# (851, 5)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851 entries, 0 to 850
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area House Age           851 non-null    float64
#  1   Avg. Area Number of Rooms     851 non-null    float64
#  2   Avg. Area Number of Bedrooms  851 non-null    float64
#  3   Price                         851 non-null    float64
#  4   Address                       851 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 33.4+ KB

# %%
d.isna().sum()
# Out:
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Price                           0
# Address                         0
# dtype: int64

# %%
d.describe()
# Out:
#        Avg. Area House Age  Avg. Area Number of Rooms  \
# count           851.000000                 851.000000
# mean              5.962219                   6.223081
# std               0.986390                   0.643383
# min               3.004717                   3.950225
# 25%               5.300213                   5.854039
# 50%               5.939370                   6.310755
# 75%               6.635657                   6.718897
# max               9.519088                   8.877240
#
#        Avg. Area Number of Bedrooms         Price
# count                    851.000000  8.510000e+02
# mean                       2.271669  1.130810e+06
# std                        0.190723  3.329965e+05
# min                        2.000000  1.515271e+05
# 25%                        2.130000  9.064830e+05
# 50%                        2.270000  1.124043e+06
# 75%                        2.380000  1.369214e+06
# max                        3.000000  2.030911e+06

# %%
d.hist(figsize=(10,6))
# Out:
# array([[<AxesSubplot:title={'center':'Avg. Area House Age'}>,
#         <AxesSubplot:title={'center':'Avg. Area Number of Rooms'}>],
#        [<AxesSubplot:title={'center':'Avg. Area Number of Bedrooms'}>,
#         <AxesSubplot:title={'center':'Price'}>]], dtype=object)

# %%
d.columns
# Out:
# Index(['Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Price', 'Address'],
#       dtype='object')

# %%
sns.distplot(d["Avg. Area Number of Rooms"])
plt.show()
sns.distplot(d["Price"])
plt.show()

# %%
sns.pairplot(d)

# %%
sns.scatterplot(y=d["Avg. Area Number of Rooms"],x=d["Price"])
plt.title("Rooms Vs Price",size=16)
plt.ylabel("No. of Rooms",size=14)
plt.xlabel("Price",size=15)
plt.show()

# %%
sns.regplot(y=d["Price"],x=d["Avg. Area Number of Rooms"])
plt.title("Regression Plot",size=16)
plt.ylabel("No of rooms",size=14)
plt.xlabel("Price",size=15)
plt.show()

# %%
sns.heatmap(d.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
x=d.iloc[:,:-1].values
y=d.iloc[:,1].values

# %%
x
# Out:
# array([[6.98977975e+00, 6.62047799e+00, 2.42000000e+00, 1.57393656e+06],
#        [5.36212557e+00, 6.39312098e+00, 2.30000000e+00, 7.98869533e+05],
#        [6.91953483e+00, 5.99318790e+00, 2.27000000e+00, 1.29133152e+06],
#        ...,
#        [5.78920257e+00, 6.41531242e+00, 2.02000000e+00, 1.40686550e+06],
#        [6.03627486e+00, 6.53811093e+00, 2.22000000e+00, 1.37893788e+06],
#        [7.25059062e+00, 4.80508098e+00, 2.13000000e+00, 1.03072958e+06]])

# %%
y
# Out:
# array([6.62047799, 6.39312098, 5.9931879 , 6.51717504, 6.99269876,
#        6.5930456 , 5.42690286, 6.71390544, 5.03452535, 6.91920414,
#        6.91174261, 6.31648002, 6.03848798, 6.00126136, 5.89705284,
#        4.41438087, 6.15970522, 6.2916008 , 5.58090594, 6.61109601,
#        5.16486548, 5.66106413, 6.6908949 , 5.30500041, 6.81867075,
#        8.87724004, 5.93590933, 6.70391722, 6.73308487, 5.63677939,
#        6.19479433, 6.68823017, 6.88820563, 5.37038661, 5.90502434,
#        5.9297338 , 6.85153583, 6.84415015, 6.964616  , 5.35511362,
#        5.7360294 , 6.8282473 , 6.06088466, 6.76583256, 5.68706258,
#        6.03279526, 4.95438746, 6.03662122, 5.51883502, 6.33361693,
#        6.33262673, 6.95219577, 4.80738746, 6.86860389, 5.65269448,
#        6.82966744, 4.65197429, 4.67913425, 6.25275736, 5.45065852,
#        6.64944766, 6.04829539, 6.50944919, 6.9819843 , 6.9812466 ,
#        5.19725391, 6.86086039, 6.23229587, 5.01491652, 6.01074282,
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
l=LinearRegression()
l.fit(x_train,y_train)
print("train test complete")
# Out:
# train test complete

# %%
y_pred=l.predict(x_test)

# %%
d1=pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
d1
# Out:
#        Actual  Predicted
# 0    6.888195   6.888195
# 1    6.114323   6.114323
# 2    5.232616   5.232616
# 3    5.275145   5.275145
# 4    6.499062   6.499062
# ..        ...        ...
# 166  6.079424   6.079424
# 167  5.909452   5.909452
# 168  6.616481   6.616481
# 169  6.332627   6.332627
# 170  6.896914   6.896914
#
# [171 rows x 2 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (638, 4)
# (213, 4)
# (638,)
# (213,)

# %%
###Specify the split size manually by specifying the parameters of test size

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (765, 4)
# (86, 4)
# (765,)
# (86,)

# %% [markdown]
# ### Print the mean vaules

# %%
print(np.mean(x_train))
print(np.mean(x_test))
print(np.mean(y_train))
print(np.mean(y_test))
# Out:
# 281552.28841983015
# 292970.3703465847
# 6.222527297579084
# 6.228007335302326

# %%
## for 0-it gives fixed means, for 1- evey time mean changes
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=1)

# %%
print(np.mean(x_train))
print(np.mean(x_test))
print(np.mean(y_train))
print(np.mean(y_test))
# Out:
# 282313.20380862313
# 286201.7625276706
# 6.234643866882353
# 6.120226224639536

# %%
from sklearn.linear_model import LinearRegression
l=LinearRegression()
l.fit(x_train,y_train)
print("train test complete")
# Out:
# train test complete

# %%
y_pred=l.predict(x_test)

# %%
d1=pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
d1
# Out:
#       Actual  Predicted
# 0   6.578205   6.578205
# 1   6.218126   6.218126
# 2   4.049321   4.049321
# 3   6.951617   6.951617
# 4   6.085444   6.085444
# ..       ...        ...
# 81  4.969158   4.969158
# 82  5.839050   5.839050
# 83  6.649448   6.649448
# 84  6.455830   6.455830
# 85  5.397884   5.397884
#
# [86 rows x 2 columns]

# %%
from sklearn.metrics import mean_absolute_error
print("Mean Absolute error",mean_absolute_error(y_test,y_pred))
# Out:
# Mean Absolute error 2.2760232974802463e-11

# %%
sns.regplot(x=y_test,y=y_pred)
plt.title("Regression plot",size=12)
plt.ylabel("Price",size=15)
plt.xlabel("Avg. Area Number of Rooms",size=12)
plt.show()
